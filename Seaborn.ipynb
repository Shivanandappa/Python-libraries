# %% [markdown]
# Seaborn Tutorial
#
# Distribution plots
#
# > distplot
# > joinplot
# > pairplot
#
# Practise problem on IRIS Dataset

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
df = sns.load_dataset("tips")

# %%
import sys
sys.path
# Out:
# ['/home/jay/Untitled Folder 2',
#  '/usr/lib/python38.zip',
#  '/usr/lib/python3.8',
#  '/usr/lib/python3.8/lib-dynload',
#  '',
#  '/home/jay/.local/lib/python3.8/site-packages',
#  '/usr/local/lib/python3.8/dist-packages',
#  '/usr/lib/python3/dist-packages',
#  '/usr/lib/python3/dist-packages/IPython/extensions',
#  '/home/jay/.ipython']

# %%
## no module found names 'seaborn'

# %%
import pip
pip.main(['install','seaborn'])
# Out:
# WARNING: pip is being invoked by an old script wrapper. This will fail in a future version of pip.
# Please see https://github.com/pypa/pip/issues/5599 for advice on fixing the underlying issue.
# To avoid this problem you can invoke Python with '-m pip' instead of running pip directly.
# ...
# 0

# %%
import seaborn as sns

# %%
#univarate analysis  f1
# bivariate analysis f1,f2

# %%
df = sns.load_dataset("tips")

# %%
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %% [markdown]
# Correlation with Heatmap
#
# A correlation heatmap uses colored cells, typically in a monochromatic scale,to show a 2D correlation matrix (table)
# between two discrete dimensions or event types. it is very important in Features selection

# %%
df.corr()
# Out:
#             total_bill       tip      size
# total_bill    1.000000  0.675734  0.598315
# tip           0.675734  1.000000  0.489299
# size          0.598315  0.489299  1.000000

# %%
sns.heatmap(df.corr())

# %% [markdown]
# JoinPlot
#
# A join plot allows to study the relationship between 2 numeric variables. The central chart display their
# correlation. It is usually a scatterplot, a hexbin plot, a 2D histogram or a 2D density plot

# %% [markdown]
# Univariate Analysis

# %%
sns.jointplot(x='tip',y='total_bill',data = df,kind = 'hex')

# %%
sns.jointplot(x='tip',y='total_bill',data = df,kind = 'reg')
# Out:
# /usr/lib/python3/dist-packages/matplotlib/cbook/__init__.py:1402: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   ndim = x[:, None].ndim
# /usr/lib/python3/dist-packages/matplotlib/axes/_base.py:276: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   x = x[:, np.newaxis]
# /usr/lib/python3/dist-packages/matplotlib/axes/_base.py:278: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   y = y[:, np.newaxis]
# ...

# %%
Pair plot

A "Pairs plot" is also known as a scatterplot, in which one variable in the same data row is matched with another
variable's value,like this: pairs plots are just elaborations on this ,showing all variables paires with all the 
other variables.
# Out:
#   File "<ipython-input-19-9edba4bb8044>", line 1
#     Pair plot
#          ^
# SyntaxError: invalid syntax

# %%
sns.pairplot(df)

# %% [markdown]
# Pairplot
#
# A "Pair plot " is also known as a scatterplot, in which one variable in the same data row is matched with another
# variable's value,like this: Pairs plots are just elaborations on this, showing all varialbes paired with all the
# other variables.

# %%
sns.pairplot(df)

# %%
sns.pairplot(df,hue = 'sex')

# %%
sns.pairplot(df,hue = 'smoker')

# %% [markdown]
#  Dist plot
#
#     Dist plot helps us to check the distribution of the column feature

# %%
sns.distplot(df['tip'])
# Out:
# /home/jay/.local/lib/python3.8/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /usr/lib/python3/dist-packages/matplotlib/cbook/__init__.py:1402: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   ndim = x[:, None].ndim
# /usr/lib/python3/dist-packages/matplotlib/axes/_base.py:276: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   x = x[:, np.newaxis]
# ...

# %%
sns.distplot(df['tip'],kde = False,bins = 10)
# Out:
# /home/jay/.local/lib/python3.8/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# Categorical Plots
#
# Seaborn also helps us in doing the analysis on categorical Data points. In this section we will discuss about.
#
# > Boxplot
#
# > violinplot
#
# > Countplot
#
# > barplot

# %%
## Count plot ## by defualt it will be taken as x axis

sns.countplot( 'sex', data = df)

# %%
## Count plot

sns.countplot(y= 'sex', data = df)

# %%
 ## Count plot

sns.countplot('smoker', data = df)

# %%
## Bar plot

sns.barplot(y='total_bill', x = 'smoker', data = df)

# %%
## Bar plot

sns.barplot(x='sex', y = 'total_bill', data = df)

# %% [markdown]
# Box plot
#
# A box and whisker plot (sometimes called a boxplot) is a graph that presents information from a five-number summary.

# %%
sns.boxplot('smoker','total_bill',data=df)
# Out:
# /home/jay/.local/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
sns.boxplot('sex','total_bill',data=df)
# Out:
# /home/jay/.local/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
sns.boxplot(x="day" , y = "total_bill",data = df)

# %%
sns.boxplot(x="day" , y = "total_bill",data = df,palette = 'rainbow')

# %%
sns.boxplot(data = df,orient = 'v')

# %%
# categorize my data based on some other categories 

sns.boxplot(x="total_bill",y="day",hue="smoker",data=df)

# %% [markdown]
# Violin Plot
#
# Violin plot helps us to see both the distribution of data in terms of kernel density estimation and the box plot.

# %%
sns.violinplot(x="total_bill", y = "day", data = df,palette = 'rainbow')

# %%
## practise Homework

iris = sns.load_dataset('iris')
